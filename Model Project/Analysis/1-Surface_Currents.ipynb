# %% [markdown]
# # Assessing Model Results
#
# This notebook serves as a demo for an initial assessment of Mike's Calfornia Current regional model. You can follow and/or adapt this notebook based on your configuration if you are using a regional domain.
#
# First, import packages to re-create and visualize the model fields here:

# %%
import os
import imageio_ffmpeg

# Force MoviePy / imageio to use the bundled ffmpeg
os.environ["IMAGEIO_FFMPEG_EXE"] = imageio_ffmpeg.get_ffmpeg_exe()
print("Using ffmpeg at:", os.environ["IMAGEIO_FFMPEG_EXE"])
# Out:
# Using ffmpeg at: /opt/anaconda3/envs/ms274_video/lib/python3.11/site-packages/imageio_ffmpeg/binaries/ffmpeg-macos-x86_64-v7.1

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.gridspec import GridSpec
from matplotlib.patches import Rectangle
import moviepy.video.io.ImageSequenceClip

# %% [markdown]
# Next, define the location of the run directory for the model. This is the directory that holds all of the output from the model.

# %%
# define the input directory
run_dir = '/Users/masonjones/Desktop/MS274/model/run1/diags'

# %% [markdown]
# Then, re-create the model grid

# %%
delX = 547/8000000
delY = 225291667/1000000000000
xgOrigin = -121.79820967558051
ygOrigin = 36.774869659553836
n_rows = 240
n_cols = 240

# recreate the grids that will be used in the model
xc = np.arange(xgOrigin+delX/2, xgOrigin+n_cols*delX, delX)
yc = np.arange(ygOrigin+delY/2, ygOrigin+n_rows*delY, delY)
XC, YC = np.meshgrid(xc, yc)

# %% [markdown]
# ## Plot a model field at one timestep
# A good first assessment of a model is to plot some of the output fields. Here, I'll choose one of the surface temperature fields. I'll first read in the field, and then I'll plot it

# %%
grid = np.fromfile(os.path.join(run_dir,'vel_3D_mon_snap',
                                'vel_3D_mon_snap.0000000900.data'), '>f4')
grid = grid.reshape((2,140,n_rows,n_cols))

U = grid[0]  # UVEL
V = grid[1] #VVEL

# %%
plt.figure(figsize=(6, 12))
C = plt.pcolormesh(grid[0,0,:,:-1], cmap='turbo', vmin=-0.05,vmax=0.08)
plt.colorbar(C)
plt.show()

# %% [markdown]
# ## Make a timeseries
# After plotting a few fields, next we can see how the model is evolving through time. For this example, I'll choose a point in the domain near the coast and I'll plot that on a map to ensure it's in the right location:

# %%
row = 125
col = 150
plt.figure(figsize=(12, 20))
C = plt.pcolormesh(grid[0,0,:,:-1], cmap='turbo', vmin=-0.08,vmax=0.08)
plt.plot(col,row,'w.')
plt.colorbar(C)
plt.show()

# %% [markdown]
# When I'm happy with the location of the point, I'll loop through all of the output files to generate a timeseries:

# %%
timestep_numbers = []
vel_values = []

folder = os.path.join(run_dir, 'vel_3D_mon_snap')

Nx = n_cols  # 240
Ny = n_rows  # 240
Nz = 140     # from meta file
Nf = 2       # UVEL + VVEL

expected_size = Nx * Ny * Nz * Nf * 4  # bytes

for file_name in sorted(os.listdir(folder)):
    if file_name.endswith('.data'):
        path = os.path.join(folder, file_name)

        size = os.path.getsize(path)
        print(f"{file_name}: {size} bytes")

        if size != expected_size:
            print(f"❌ ERROR: wrong file size, cannot reshape {file_name}")
            continue

        # safe read
        grid = np.fromfile(path, dtype='>f4')

        try:
            grid = grid.reshape((Nf, Nz, Ny, Nx))
        except Exception as e:
            print(f"❌ RESHAPE FAILED for {file_name}: {e}")
            continue

        timestep_numbers.append(int(file_name.split('.')[-2]))
        vel_values.append(grid[0, 0, row, col])  # UVEL at surface
# Out:
# vel_3D_mon_snap.0000000900.data: 64512000 bytes
# vel_3D_mon_snap.0000002700.data: 64512000 bytes
# vel_3D_mon_snap.0000004500.data: 64512000 bytes
# vel_3D_mon_snap.0000006300.data: 64512000 bytes
# vel_3D_mon_snap.0000008100.data: 64512000 bytes
# vel_3D_mon_snap.0000009900.data: 64512000 bytes
# vel_3D_mon_snap.0000011700.data: 64512000 bytes
# vel_3D_mon_snap.0000013500.data: 64512000 bytes
# vel_3D_mon_snap.0000015300.data: 64512000 bytes
# vel_3D_mon_snap.0000017100.data: 64512000 bytes
# vel_3D_mon_snap.0000018900.data: 64512000 bytes
# vel_3D_mon_snap.0000020700.data: 64512000 bytes
# vel_3D_mon_snap.0000022500.data: 64512000 bytes
# vel_3D_mon_snap.0000024300.data: 64512000 bytes
# vel_3D_mon_snap.0000027900.data: 64512000 bytes
# vel_3D_mon_snap.0000029700.data: 64512000 bytes
# vel_3D_mon_snap.0000031500.data: 64512000 bytes
# vel_3D_mon_snap.0000033300.data: 64512000 bytes
# vel_3D_mon_snap.0000035100.data: 64512000 bytes
# vel_3D_mon_snap.0000036900.data: 64512000 bytes
# vel_3D_mon_snap.0000038700.data: 64512000 bytes
# vel_3D_mon_snap.0000040500.data: 64512000 bytes
# vel_3D_mon_snap.0000042300.data: 64512000 bytes
# vel_3D_mon_snap.0000044100.data: 64512000 bytes
# vel_3D_mon_snap.0000045900.data: 64512000 bytes
# vel_3D_mon_snap.0000047700.data: 64512000 bytes
# vel_3D_mon_snap.0000049500.data: 64512000 bytes
# vel_3D_mon_snap.0000051300.data: 64512000 bytes
# vel_3D_mon_snap.0000053100.data: 64512000 bytes
# vel_3D_mon_snap.0000054900.data: 64512000 bytes
# vel_3D_mon_snap.0000056700.data: 64512000 bytes
# vel_3D_mon_snap.0000058500.data: 64512000 bytes
# vel_3D_mon_snap.0000060300.data: 64512000 bytes
# vel_3D_mon_snap.0000062100.data: 64512000 bytes
# vel_3D_mon_snap.0000063900.data: 64512000 bytes
# vel_3D_mon_snap.0000065700.data: 64512000 bytes
# vel_3D_mon_snap.0000067500.data: 64512000 bytes
# vel_3D_mon_snap.0000069300.data: 64512000 bytes
# vel_3D_mon_snap.0000071100.data: 64512000 bytes
# vel_3D_mon_snap.0000072900.data: 64512000 bytes
# vel_3D_mon_snap.0000074700.data: 64512000 bytes
# vel_3D_mon_snap.0000076500.data: 64512000 bytes
# vel_3D_mon_snap.0000078300.data: 64512000 bytes
# vel_3D_mon_snap.0000080100.data: 64512000 bytes
# vel_3D_mon_snap.0000081900.data: 64512000 bytes
# vel_3D_mon_snap.0000083700.data: 64512000 bytes
# vel_3D_mon_snap.0000085500.data: 64512000 bytes
# vel_3D_mon_snap.0000087300.data: 64512000 bytes
# vel_3D_mon_snap.0000089100.data: 64512000 bytes
# vel_3D_mon_snap.0000092700.data: 64512000 bytes
# vel_3D_mon_snap.0000094500.data: 64512000 bytes
# vel_3D_mon_snap.0000096300.data: 64512000 bytes
# vel_3D_mon_snap.0000098100.data: 64512000 bytes
# vel_3D_mon_snap.0000099900.data: 64512000 bytes
# vel_3D_mon_snap.0000101700.data: 64512000 bytes
# vel_3D_mon_snap.0000103500.data: 64512000 bytes
# vel_3D_mon_snap.0000105300.data: 64512000 bytes
# vel_3D_mon_snap.0000107100.data: 64512000 bytes
# vel_3D_mon_snap.0000108900.data: 64512000 bytes
# vel_3D_mon_snap.0000110700.data: 64512000 bytes
# vel_3D_mon_snap.0000112500.data: 64512000 bytes
# vel_3D_mon_snap.0000114300.data: 64512000 bytes
# vel_3D_mon_snap.0000116100.data: 64512000 bytes
# vel_3D_mon_snap.0000117900.data: 64512000 bytes
# vel_3D_mon_snap.0000119700.data: 64512000 bytes
# vel_3D_mon_snap.0000121500.data: 64512000 bytes
# vel_3D_mon_snap.0000123300.data: 64512000 bytes
# vel_3D_mon_snap.0000125100.data: 64512000 bytes
# vel_3D_mon_snap.0000126900.data: 64512000 bytes
# vel_3D_mon_snap.0000128700.data: 64512000 bytes
# vel_3D_mon_snap.0000130500.data: 64512000 bytes
# vel_3D_mon_snap.0000132300.data: 64512000 bytes
# vel_3D_mon_snap.0000134100.data: 64512000 bytes
# vel_3D_mon_snap.0000135900.data: 64512000 bytes
# vel_3D_mon_snap.0000137700.data: 64512000 bytes
# vel_3D_mon_snap.0000139500.data: 64512000 bytes
# vel_3D_mon_snap.0000141300.data: 64512000 bytes
# vel_3D_mon_snap.0000143100.data: 64512000 bytes
# vel_3D_mon_snap.0000144900.data: 64512000 bytes
# vel_3D_mon_snap.0000146700.data: 64512000 bytes
# vel_3D_mon_snap.0000148500.data: 64512000 bytes
# vel_3D_mon_snap.0000150300.data: 64512000 bytes
# vel_3D_mon_snap.0000152100.data: 64512000 bytes
# vel_3D_mon_snap.0000153900.data: 64512000 bytes
# vel_3D_mon_snap.0000155700.data: 64512000 bytes
# vel_3D_mon_snap.0000157500.data: 64512000 bytes
# vel_3D_mon_snap.0000159300.data: 64512000 bytes
# vel_3D_mon_snap.0000161100.data: 64512000 bytes
# vel_3D_mon_snap.0000162900.data: 64512000 bytes
# vel_3D_mon_snap.0000164700.data: 64512000 bytes
# vel_3D_mon_snap.0000166500.data: 64512000 bytes
# vel_3D_mon_snap.0000168300.data: 64512000 bytes
# vel_3D_mon_snap.0000170100.data: 64512000 bytes
# vel_3D_mon_snap.0000171900.data: 64512000 bytes
# vel_3D_mon_snap.0000173700.data: 64512000 bytes
# vel_3D_mon_snap.0000175500.data: 64512000 bytes
# vel_3D_mon_snap.0000177300.data: 64512000 bytes
# vel_3D_mon_snap.0000179100.data: 64512000 bytes
# vel_3D_mon_snap.0000180900.data: 64512000 bytes
# vel_3D_mon_snap.0000182700.data: 64512000 bytes
# vel_3D_mon_snap.0000184500.data: 64512000 bytes
# vel_3D_mon_snap.0000186300.data: 64512000 bytes
# vel_3D_mon_snap.0000188100.data: 64512000 bytes
# vel_3D_mon_snap.0000189900.data: 64512000 bytes
# vel_3D_mon_snap.0000191700.data: 64512000 bytes
# vel_3D_mon_snap.0000773100.data: 64512000 bytes
# vel_3D_mon_snap.0000774900.data: 64512000 bytes
# vel_3D_mon_snap.0000776700.data: 64512000 bytes
# vel_3D_mon_snap.0000778500.data: 64512000 bytes
# vel_3D_mon_snap.0000780300.data: 64512000 bytes
# vel_3D_mon_snap.0000782100.data: 64512000 bytes
# vel_3D_mon_snap.0000783900.data: 64512000 bytes
# vel_3D_mon_snap.0000785700.data: 64512000 bytes
# vel_3D_mon_snap.0000787500.data: 64512000 bytes
# vel_3D_mon_snap.0000789300.data: 64512000 bytes
# vel_3D_mon_snap.0000791100.data: 64512000 bytes
# vel_3D_mon_snap.0000792900.data: 64512000 bytes
# vel_3D_mon_snap.0000794700.data: 64512000 bytes
# vel_3D_mon_snap.0000796500.data: 64512000 bytes
# vel_3D_mon_snap.0000798300.data: 64512000 bytes
# vel_3D_mon_snap.0000800100.data: 64512000 bytes
# vel_3D_mon_snap.0000801900.data: 64512000 bytes
# vel_3D_mon_snap.0000803700.data: 64512000 bytes
# vel_3D_mon_snap.0000805500.data: 64512000 bytes
# vel_3D_mon_snap.0000807300.data: 64512000 bytes
# vel_3D_mon_snap.0000809100.data: 64512000 bytes
# vel_3D_mon_snap.0000810900.data: 64512000 bytes
# vel_3D_mon_snap.0000812700.data: 64512000 bytes
# vel_3D_mon_snap.0000814500.data: 64512000 bytes
# vel_3D_mon_snap.0000816300.data: 64512000 bytes
# vel_3D_mon_snap.0000818100.data: 64512000 bytes
# vel_3D_mon_snap.0000819900.data: 64512000 bytes
# vel_3D_mon_snap.0000821700.data: 64512000 bytes
# vel_3D_mon_snap.0000823500.data: 64512000 bytes
# vel_3D_mon_snap.0000825300.data: 64512000 bytes
# vel_3D_mon_snap.0000827100.data: 64512000 bytes
# vel_3D_mon_snap.0000830700.data: 64512000 bytes
# vel_3D_mon_snap.0000832500.data: 64512000 bytes
# vel_3D_mon_snap.0000834300.data: 64512000 bytes
# vel_3D_mon_snap.0000836100.data: 64512000 bytes
# vel_3D_mon_snap.0000837900.data: 64512000 bytes
# vel_3D_mon_snap.0000839700.data: 64512000 bytes
# vel_3D_mon_snap.0000841500.data: 64512000 bytes
# vel_3D_mon_snap.0000843300.data: 64512000 bytes
# vel_3D_mon_snap.0000845100.data: 64512000 bytes
# vel_3D_mon_snap.0000846900.data: 64512000 bytes
# vel_3D_mon_snap.0000848700.data: 64512000 bytes
# vel_3D_mon_snap.0000850500.data: 64512000 bytes
# vel_3D_mon_snap.0000852300.data: 64512000 bytes
# vel_3D_mon_snap.0000854100.data: 64512000 bytes
# vel_3D_mon_snap.0000855900.data: 64512000 bytes
# vel_3D_mon_snap.0000857700.data: 64512000 bytes
# vel_3D_mon_snap.0000859500.data: 64512000 bytes
# vel_3D_mon_snap.0000861300.data: 64512000 bytes
# vel_3D_mon_snap.0000863100.data: 64512000 bytes
# vel_3D_mon_snap.0000864900.data: 64512000 bytes
# vel_3D_mon_snap.0000866700.data: 64512000 bytes
# vel_3D_mon_snap.0000868500.data: 64512000 bytes
# vel_3D_mon_snap.0000965700.data: 64512000 bytes
# vel_3D_mon_snap.0000967500.data: 64512000 bytes
# vel_3D_mon_snap.0000969300.data: 64512000 bytes
# vel_3D_mon_snap.0000971100.data: 64512000 bytes
# vel_3D_mon_snap.0000972900.data: 64512000 bytes
# vel_3D_mon_snap.0000974700.data: 64512000 bytes
# vel_3D_mon_snap.0000976500.data: 64512000 bytes
# vel_3D_mon_snap.0000978300.data: 64512000 bytes
# vel_3D_mon_snap.0000980100.data: 64512000 bytes
# vel_3D_mon_snap.0000981900.data: 64512000 bytes
# vel_3D_mon_snap.0000983700.data: 64512000 bytes
# vel_3D_mon_snap.0000985500.data: 64512000 bytes
# vel_3D_mon_snap.0000987300.data: 64512000 bytes
# vel_3D_mon_snap.0000989100.data: 64512000 bytes
# vel_3D_mon_snap.0000990900.data: 64512000 bytes
# vel_3D_mon_snap.0000992700.data: 64512000 bytes
# vel_3D_mon_snap.0000994500.data: 64512000 bytes
# vel_3D_mon_snap.0000996300.data: 64512000 bytes
# vel_3D_mon_snap.0000998100.data: 64512000 bytes
# vel_3D_mon_snap.0000999900.data: 64512000 bytes
# vel_3D_mon_snap.0001001700.data: 64512000 bytes
# vel_3D_mon_snap.0001003500.data: 64512000 bytes
# vel_3D_mon_snap.0001005300.data: 64512000 bytes
# vel_3D_mon_snap.0001007100.data: 64512000 bytes
# vel_3D_mon_snap.0001008900.data: 64512000 bytes
# vel_3D_mon_snap.0001010700.data: 64512000 bytes
# vel_3D_mon_snap.0001012500.data: 64512000 bytes
# vel_3D_mon_snap.0001014300.data: 64512000 bytes
# vel_3D_mon_snap.0001016100.data: 64512000 bytes
# vel_3D_mon_snap.0001017900.data: 64512000 bytes
# vel_3D_mon_snap.0001019700.data: 64512000 bytes
# vel_3D_mon_snap.0001021500.data: 64512000 bytes
# vel_3D_mon_snap.0001023300.data: 64512000 bytes
# vel_3D_mon_snap.0001025100.data: 64512000 bytes
# vel_3D_mon_snap.0001026900.data: 64512000 bytes
# vel_3D_mon_snap.0001028700.data: 64512000 bytes
# vel_3D_mon_snap.0001030500.data: 64512000 bytes
# vel_3D_mon_snap.0001032300.data: 64512000 bytes
# vel_3D_mon_snap.0001034100.data: 64512000 bytes
# vel_3D_mon_snap.0001035900.data: 64512000 bytes
# vel_3D_mon_snap.0001037700.data: 64512000 bytes
# vel_3D_mon_snap.0001039500.data: 64512000 bytes
# vel_3D_mon_snap.0001041300.data: 64512000 bytes
# vel_3D_mon_snap.0001043100.data: 64512000 bytes
# vel_3D_mon_snap.0001044900.data: 64512000 bytes
# vel_3D_mon_snap.0001046700.data: 64512000 bytes
# vel_3D_mon_snap.0001048500.data: 64512000 bytes
# vel_3D_mon_snap.0001050300.data: 64512000 bytes
# vel_3D_mon_snap.0001052100.data: 64512000 bytes
# vel_3D_mon_snap.0001053900.data: 64512000 bytes
# vel_3D_mon_snap.0001055700.data: 64512000 bytes
# vel_3D_mon_snap.0001057500.data: 64512000 bytes
# vel_3D_mon_snap.0001059300.data: 64512000 bytes
# vel_3D_mon_snap.0001061100.data: 64512000 bytes
# vel_3D_mon_snap.0001062900.data: 64512000 bytes
# vel_3D_mon_snap.0001064700.data: 64512000 bytes
# vel_3D_mon_snap.0001066500.data: 64512000 bytes
# vel_3D_mon_snap.0001068300.data: 64512000 bytes
# vel_3D_mon_snap.0001070100.data: 64512000 bytes
# vel_3D_mon_snap.0001071900.data: 64512000 bytes
# vel_3D_mon_snap.0001073700.data: 64512000 bytes
# vel_3D_mon_snap.0001075500.data: 64512000 bytes
# vel_3D_mon_snap.0001077300.data: 64512000 bytes
# vel_3D_mon_snap.0001079100.data: 64512000 bytes
# vel_3D_mon_snap.0001080900.data: 64512000 bytes
# vel_3D_mon_snap.0001082700.data: 64512000 bytes
# vel_3D_mon_snap.0001084500.data: 64512000 bytes
# vel_3D_mon_snap.0001086300.data: 64512000 bytes
# vel_3D_mon_snap.0001088100.data: 64512000 bytes
# vel_3D_mon_snap.0001091700.data: 64512000 bytes
# vel_3D_mon_snap.0001093500.data: 64512000 bytes
# vel_3D_mon_snap.0001095300.data: 64512000 bytes
# vel_3D_mon_snap.0001097100.data: 64512000 bytes
# vel_3D_mon_snap.0001098900.data: 64512000 bytes
# vel_3D_mon_snap.0001100700.data: 64512000 bytes
# vel_3D_mon_snap.0001102500.data: 64512000 bytes
# vel_3D_mon_snap.0001104300.data: 64512000 bytes
# vel_3D_mon_snap.0001106100.data: 64512000 bytes
# vel_3D_mon_snap.0001107900.data: 64512000 bytes
# vel_3D_mon_snap.0001109700.data: 64512000 bytes
# vel_3D_mon_snap.0001111500.data: 64512000 bytes
# vel_3D_mon_snap.0001113300.data: 64512000 bytes
# vel_3D_mon_snap.0001115100.data: 64512000 bytes
# vel_3D_mon_snap.0001116900.data: 64512000 bytes
# vel_3D_mon_snap.0001118700.data: 64512000 bytes
# vel_3D_mon_snap.0001120500.data: 64512000 bytes
# vel_3D_mon_snap.0001122300.data: 64512000 bytes
# vel_3D_mon_snap.0001124100.data: 64512000 bytes
# vel_3D_mon_snap.0001125900.data: 64512000 bytes
# vel_3D_mon_snap.0001127700.data: 64512000 bytes
# vel_3D_mon_snap.0001129500.data: 64512000 bytes
# vel_3D_mon_snap.0001131300.data: 64512000 bytes
# vel_3D_mon_snap.0001133100.data: 64512000 bytes
# vel_3D_mon_snap.0001134900.data: 64512000 bytes
# vel_3D_mon_snap.0001136700.data: 64512000 bytes
# vel_3D_mon_snap.0001138500.data: 64512000 bytes
# vel_3D_mon_snap.0001140300.data: 64512000 bytes
# vel_3D_mon_snap.0001142100.data: 64512000 bytes
# vel_3D_mon_snap.0001143900.data: 64512000 bytes
# vel_3D_mon_snap.0001145700.data: 64512000 bytes
# vel_3D_mon_snap.0001147500.data: 64512000 bytes
# vel_3D_mon_snap.0001149300.data: 64512000 bytes
# vel_3D_mon_snap.0001151100.data: 64512000 bytes
# vel_3D_mon_snap.0001152900.data: 64512000 bytes
# vel_3D_mon_snap.0001154700.data: 64512000 bytes
# vel_3D_mon_snap.0001156500.data: 64512000 bytes
# vel_3D_mon_snap.0001158300.data: 64512000 bytes
# vel_3D_mon_snap.0001160100.data: 64512000 bytes
# vel_3D_mon_snap.0001161900.data: 64512000 bytes
# vel_3D_mon_snap.0001163700.data: 64512000 bytes
# vel_3D_mon_snap.0001165500.data: 64512000 bytes
# vel_3D_mon_snap.0001167300.data: 64512000 bytes
# vel_3D_mon_snap.0001169100.data: 64512000 bytes
# vel_3D_mon_snap.0001170900.data: 64512000 bytes
# vel_3D_mon_snap.0001172700.data: 64512000 bytes
# vel_3D_mon_snap.0001174500.data: 64512000 bytes
# vel_3D_mon_snap.0001176300.data: 64512000 bytes
# vel_3D_mon_snap.0001178100.data: 64512000 bytes
# vel_3D_mon_snap.0001179900.data: 64512000 bytes
# vel_3D_mon_snap.0001181700.data: 64512000 bytes
# vel_3D_mon_snap.0001183500.data: 64512000 bytes
# vel_3D_mon_snap.0001185300.data: 64512000 bytes
# vel_3D_mon_snap.0001187100.data: 64512000 bytes
# vel_3D_mon_snap.0001188900.data: 64512000 bytes
# vel_3D_mon_snap.0001192500.data: 64512000 bytes
# vel_3D_mon_snap.0001194300.data: 64512000 bytes
# vel_3D_mon_snap.0001196100.data: 64512000 bytes
# vel_3D_mon_snap.0001197900.data: 64512000 bytes
# vel_3D_mon_snap.0001199700.data: 64512000 bytes
# vel_3D_mon_snap.0001201500.data: 64512000 bytes
# vel_3D_mon_snap.0001203300.data: 64512000 bytes
# vel_3D_mon_snap.0001205100.data: 64512000 bytes
# vel_3D_mon_snap.0001206900.data: 64512000 bytes
# vel_3D_mon_snap.0001208700.data: 64512000 bytes
# vel_3D_mon_snap.0001210500.data: 64512000 bytes
# vel_3D_mon_snap.0001212300.data: 64512000 bytes
# vel_3D_mon_snap.0001214100.data: 64512000 bytes
# vel_3D_mon_snap.0001215900.data: 64512000 bytes
# vel_3D_mon_snap.0001217700.data: 64512000 bytes
# vel_3D_mon_snap.0001219500.data: 64512000 bytes
# vel_3D_mon_snap.0001221300.data: 64512000 bytes
# vel_3D_mon_snap.0001223100.data: 64512000 bytes
# vel_3D_mon_snap.0001224900.data: 64512000 bytes
# vel_3D_mon_snap.0001226700.data: 64512000 bytes
# vel_3D_mon_snap.0001228500.data: 64512000 bytes
# vel_3D_mon_snap.0001230300.data: 64512000 bytes
# vel_3D_mon_snap.0001232100.data: 64512000 bytes
# vel_3D_mon_snap.0001233900.data: 64512000 bytes
# vel_3D_mon_snap.0001235700.data: 64512000 bytes
# vel_3D_mon_snap.0001237500.data: 64512000 bytes
# vel_3D_mon_snap.0001239300.data: 64512000 bytes
# vel_3D_mon_snap.0001241100.data: 64512000 bytes
# vel_3D_mon_snap.0001242900.data: 64512000 bytes
# vel_3D_mon_snap.0001244700.data: 64512000 bytes
# vel_3D_mon_snap.0001246500.data: 64512000 bytes
# vel_3D_mon_snap.0001248300.data: 64512000 bytes
# vel_3D_mon_snap.0001250100.data: 64512000 bytes
# vel_3D_mon_snap.0001251900.data: 64512000 bytes
# vel_3D_mon_snap.0001253700.data: 64512000 bytes
# vel_3D_mon_snap.0001255500.data: 64512000 bytes
# vel_3D_mon_snap.0001257300.data: 64512000 bytes
# vel_3D_mon_snap.0001259100.data: 64512000 bytes
# vel_3D_mon_snap.0001260900.data: 64512000 bytes
# vel_3D_mon_snap.0001262700.data: 64512000 bytes
# vel_3D_mon_snap.0001264500.data: 64512000 bytes
# vel_3D_mon_snap.0001266300.data: 64512000 bytes
# vel_3D_mon_snap.0001268100.data: 64512000 bytes
# vel_3D_mon_snap.0001269900.data: 64512000 bytes
# vel_3D_mon_snap.0001271700.data: 64512000 bytes
# vel_3D_mon_snap.0001273500.data: 64512000 bytes
# vel_3D_mon_snap.0001275300.data: 64512000 bytes
# vel_3D_mon_snap.0001277100.data: 64512000 bytes
# vel_3D_mon_snap.0001278900.data: 64512000 bytes
# vel_3D_mon_snap.0001280700.data: 64512000 bytes
# vel_3D_mon_snap.0001282500.data: 64512000 bytes
# vel_3D_mon_snap.0001284300.data: 64512000 bytes
# vel_3D_mon_snap.0001286100.data: 64512000 bytes
# vel_3D_mon_snap.0001287900.data: 64512000 bytes
# vel_3D_mon_snap.0001289700.data: 64512000 bytes
# vel_3D_mon_snap.0001291500.data: 64512000 bytes
# vel_3D_mon_snap.0001293300.data: 64512000 bytes
# vel_3D_mon_snap.0001295100.data: 64512000 bytes
# vel_3D_mon_snap.0001296900.data: 64512000 bytes
# vel_3D_mon_snap.0001298700.data: 64512000 bytes
# vel_3D_mon_snap.0001300500.data: 64512000 bytes
# vel_3D_mon_snap.0001302300.data: 64512000 bytes
# vel_3D_mon_snap.0001304100.data: 64512000 bytes
# vel_3D_mon_snap.0001305900.data: 64512000 bytes
# vel_3D_mon_snap.0001307700.data: 64512000 bytes
# vel_3D_mon_snap.0001309500.data: 64512000 bytes
# vel_3D_mon_snap.0001311300.data: 64512000 bytes
# vel_3D_mon_snap.0001313100.data: 64512000 bytes
# vel_3D_mon_snap.0001314900.data: 64512000 bytes
# vel_3D_mon_snap.0001316700.data: 64512000 bytes
# vel_3D_mon_snap.0001318500.data: 64512000 bytes
# vel_3D_mon_snap.0001320300.data: 64512000 bytes
# vel_3D_mon_snap.0001322100.data: 64512000 bytes
# vel_3D_mon_snap.0001323900.data: 64512000 bytes
# vel_3D_mon_snap.0001325700.data: 64512000 bytes
# vel_3D_mon_snap.0001327500.data: 64512000 bytes
# vel_3D_mon_snap.0001329300.data: 64512000 bytes
# vel_3D_mon_snap.0001331100.data: 64512000 bytes
# vel_3D_mon_snap.0001332900.data: 64512000 bytes
# vel_3D_mon_snap.0001334700.data: 64512000 bytes
# vel_3D_mon_snap.0001336500.data: 64512000 bytes
# vel_3D_mon_snap.0001338300.data: 64512000 bytes
# vel_3D_mon_snap.0001340100.data: 64512000 bytes
# vel_3D_mon_snap.0001341900.data: 64512000 bytes
# vel_3D_mon_snap.0001343700.data: 64512000 bytes
# vel_3D_mon_snap.0001345500.data: 64512000 bytes
# vel_3D_mon_snap.0001347300.data: 64512000 bytes
# vel_3D_mon_snap.0001349100.data: 64512000 bytes
# vel_3D_mon_snap.0001350900.data: 64512000 bytes
# vel_3D_mon_snap.0001352700.data: 64512000 bytes
# vel_3D_mon_snap.0001354500.data: 64512000 bytes
# vel_3D_mon_snap.0001356300.data: 64512000 bytes
# vel_3D_mon_snap.0001358100.data: 64512000 bytes
# vel_3D_mon_snap.0001359900.data: 64512000 bytes
# vel_3D_mon_snap.0001361700.data: 64512000 bytes
# vel_3D_mon_snap.0001363500.data: 64512000 bytes
# vel_3D_mon_snap.0001365300.data: 64512000 bytes
# vel_3D_mon_snap.0001367100.data: 64512000 bytes
# vel_3D_mon_snap.0001368900.data: 64512000 bytes
# vel_3D_mon_snap.0001370700.data: 64512000 bytes
# vel_3D_mon_snap.0001372500.data: 64512000 bytes
# vel_3D_mon_snap.0001374300.data: 64512000 bytes
# vel_3D_mon_snap.0001376100.data: 64512000 bytes
# vel_3D_mon_snap.0001377900.data: 64512000 bytes
# vel_3D_mon_snap.0001379700.data: 64512000 bytes
# vel_3D_mon_snap.0001383300.data: 64512000 bytes
# vel_3D_mon_snap.0001385100.data: 64512000 bytes
# vel_3D_mon_snap.0001386900.data: 64512000 bytes
# vel_3D_mon_snap.0001388700.data: 64512000 bytes
# vel_3D_mon_snap.0001390500.data: 64512000 bytes
# vel_3D_mon_snap.0001392300.data: 64512000 bytes
# vel_3D_mon_snap.0001394100.data: 64512000 bytes
# vel_3D_mon_snap.0001395900.data: 64512000 bytes
# vel_3D_mon_snap.0001397700.data: 64512000 bytes
# vel_3D_mon_snap.0001399500.data: 64512000 bytes
# vel_3D_mon_snap.0001401300.data: 64512000 bytes
# vel_3D_mon_snap.0001403100.data: 64512000 bytes
# vel_3D_mon_snap.0001406700.data: 64512000 bytes
# vel_3D_mon_snap.0001408500.data: 64512000 bytes
# vel_3D_mon_snap.0001410300.data: 64512000 bytes
# vel_3D_mon_snap.0001412100.data: 64512000 bytes
# vel_3D_mon_snap.0001413900.data: 64512000 bytes
# vel_3D_mon_snap.0001415700.data: 64512000 bytes
# vel_3D_mon_snap.0001417500.data: 64512000 bytes
# vel_3D_mon_snap.0001419300.data: 64512000 bytes
# vel_3D_mon_snap.0001421100.data: 64512000 bytes
# vel_3D_mon_snap.0001422900.data: 64512000 bytes
# vel_3D_mon_snap.0001424700.data: 64512000 bytes
# vel_3D_mon_snap.0001426500.data: 64512000 bytes

# %%
timestep_numbers = []
vel_values = []
for file_name in sorted(os.listdir(os.path.join(run_dir,'vel_3D_mon_snap'))):
    if file_name[-4:]=='data':
        # get the timestep number
        timestep_numbers.append(int(file_name.split('.')[-2]))

        grid = np.fromfile(os.path.join(run_dir,'vel_3D_mon_snap',
                                file_name), '>f4')
        grid = grid.reshape((2,140,n_rows,n_cols))
        vel_values.append(grid[0,0,row,col])

        U = grid[0]  # UVEL
        V = grid[1] #VVEL

# %% [markdown]
# Finally, I'll plot the timeseries:

# %% [markdown]
# ## Make a movie
# The timeseries looks pretty good - let's take a look at how our model is evolving through time by making a movie. First, let's make and test a function to make the panels for our movie

# %%
plot_dir = '/Users/masonjones/Desktop/MS274/model/run1/plots'

# %%
def plot_panel(run_dir, plot_dir, file_name):

    # read in the data
    grid = np.fromfile(os.path.join(run_dir,'vel_3D_mon_snap',
                                file_name), '>f4')
    grid = grid.reshape((2,140,n_rows,n_cols))
    vel_values.append(grid[0,0,row,col])
    
    U = grid[0]  # UVEL
    V = grid[1] #VVEL
    timestep_number = int(file_name.split('.')[-2])

    # make a figure 
    fig = plt.figure(figsize=(12,20))
    gs1 = GridSpec(11, 10, left=0.1, right=0.98, bottom=0.06, top=0.95, hspace=0.05)

    # plot the temperature
    ax1 = fig.add_subplot(gs1[:-2, :])
    C = ax1.pcolormesh(XC[:,:-1], YC[:,:-1], grid[0,0,:,:-1], cmap='turbo', vmin=-0.05, vmax=0.08)
    plt.colorbar(C, label='Velocity (m/s)')

    # plot the land in grey
    #land = (grid[0,:,:-1]==0).astype(int)
    #print(np.min(land), np.max(land))
    #land = np.ma.masked_where(land, land==0)
    #print(land)
    #ax1.pcolormesh(XC[:,:-1], YC[:,:-1], land, cmap='Greys')#, vmin=-1, vmax=1)
    
    # format the axes
    plt.title('CA Surface Currents')
    plt.ylabel('Latitude')
    plt.xlabel('Longitude')

    max_timestep_number = int(366*24*60*60/3)
    ax2 = fig.add_subplot(gs1[-1, :-2])
    rect = Rectangle((0,0),timestep_number, 1, facecolor='grey', edgecolor='k')
    ax2.add_patch(rect)
    ax2.set_xlim([0, max_timestep_number])
    ax2.set_ylim([0, 1])
    ax2.set_xticks([0,max_timestep_number])
    ax2.set_xticklabels([2000,2001])
    ax2.set_yticklabels([])
    ax2.set_xlabel('Time')
    
    output_file = os.path.join(plot_dir,'panels',file_name[:-5]+'.png')
    plt.savefig(output_file, facecolor='white')
    plt.close(fig)


# test the function
#plot_panel(run_dir, plot_dir, 'TS_surf_daily_mean.0000016992.data')
#plot_panel(run_dir, plot_dir, 'TS_surf_daily_mean.0000068256.data')

# %% [markdown]
# When we're happy with the plotting function, we can use it to make the panels:

# %%
for file_name in sorted(os.listdir(os.path.join(run_dir,'vel_3D_mon_snap'))):
    if file_name[-4:]=='data':
        plot_panel(run_dir, plot_dir, file_name)

# %% [markdown]
# And then stitch everything together into a movie:

# %%
panel_list = []
for file_name in sorted(os.listdir(os.path.join(plot_dir,'panels'))):
    if file_name[-4:]=='.png':
        panel_list.append(os.path.join(plot_dir,'panels',file_name))

# %%
# set the frames per second
fps=8

# use the ImageSequenceClip module to set up the clip
clip = moviepy.video.io.ImageSequenceClip.ImageSequenceClip(panel_list, fps=fps)

# write the video to a file
clip.write_videofile(os.path.join(plot_dir,'CA Sea Surface Velocity4.mp4'))
# Out:
# MoviePy - Building video /Users/masonjones/Desktop/MS274/model/run1/plots/CA Sea Surface Velocity4.mp4.
# MoviePy - Writing video /Users/masonjones/Desktop/MS274/model/run1/plots/CA Sea Surface Velocity4.mp4
# MoviePy - Done !
# MoviePy - video ready /Users/masonjones/Desktop/MS274/model/run1/plots/CA Sea Surface Velocity4.mp4

# %% [markdown]
# This is just a first analysis with my first model run. Next, I will work to run my next model experiment and analyze the comparison.
